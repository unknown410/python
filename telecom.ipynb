# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\mani\Downloads\phone_data.csv")

# %%
df
# Out:
#      index            date   duration  item    month    network network_type
# 0        0  15/10/14 06:58     34.429  data  2014-11       data         data
# 1        1  15/10/14 06:58     13.000  call  2014-11   Vodafone       mobile
# 2        2  15/10/14 14:46     23.000  call  2014-11     Meteor       mobile
# 3        3  15/10/14 14:48      4.000  call  2014-11      Tesco       mobile
# 4        4  15/10/14 17:27      4.000  call  2014-11      Tesco       mobile
# 5        5  15/10/14 18:55      4.000  call  2014-11      Tesco       mobile
# 6        6  16/10/14 06:58     34.429  data  2014-11       data         data
# 7        7  16/10/14 15:01    602.000  call  2014-11      Three       mobile
# 8        8  16/10/14 15:12   1050.000  call  2014-11      Three       mobile
# 9        9  16/10/14 15:30     19.000  call  2014-11  voicemail    voicemail
# 10      10  16/10/14 16:21   1183.000  call  2014-11      Three       mobile
# ...

# %%
print(f"The longest phone call/data entrty is {max(df.duration)}")
# Out:
# The longest phone call/data entrty is 10528.0

# %%
print(f"phone calls are recorded in total {df[df.item=='call'].duration.sum()} second")
# Out:
# phone calls are recorded in total 92321.0 second

# %%
lst1=df.month

# %%
lst1=list(lst1)

# %%
lst=set(df.month)

# %%
type(lst)
# Out:
# set

# %%
lst
# Out:
# {'2014-11', '2014-12', '2015-01', '2015-02', '2015-03'}

# %%
lst=list(lst)

# %%
for i in range(len(lst)):
    print(f"In {lst[i]} Data enteries are {lst1.count(lst[i])}")
# Out:
# In 2014-11 Data enteries are 230
# In 2015-01 Data enteries are 205
# In 2015-03 Data enteries are 101
# In 2014-12 Data enteries are 157
# In 2015-02 Data enteries are 137

# %%
df.groupby("month").index.count()
# Out:
# month
# 2014-11    230
# 2014-12    157
# 2015-01    205
# 2015-02    137
# 2015-03    101
# Name: index, dtype: int64

# %%
len(df.groupby("network"))
# Out:
# 9

# %%
df.groupby("month").

# %%
df.groupby("month").duration.sum()
# Out:
# month
# 2014-11    26639.441
# 2014-12    14641.870
# 2015-01    18223.299
# 2015-02    15522.299
# 2015-03    22750.441
# Name: duration, dtype: float64

# %%
df.groupby("month").date.count()
# Out:
# month
# 2014-11    230
# 2014-12    157
# 2015-01    205
# 2015-02    137
# 2015-03    101
# Name: date, dtype: int64

# %%
df.groupby("network")[df.item=="call"].duration.sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-04777338e486> in <module>
# ----> 1 df.groupby("network")[df.item=="call"].duration.sum()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     255                 bad_keys = list(set(key).difference(self.obj.columns))
#     256                 raise KeyError("Columns not found: {missing}"
# --> 257                                .format(missing=str(bad_keys)[1:-1]))
#     258             return self._gotitem(list(key), ndim=2)
#     259
#
# KeyError: 'Columns not found: False, True'
