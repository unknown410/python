# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
cast = pd.read_csv(r'C:\Users\mani\Python\cast.csv')
cast.head()
# Out:
#                                title  year       name   type character     n
# 0                    Suuri illusioni  1985     Homo $  actor    Guests  22.0
# 1     Gangsta Rap: The Glockumentary  2007  Too $hort  actor   Himself   NaN
# 2                  Menace II Society  1993  Too $hort  actor   Lew-Loc  27.0
# 3  Porndogs: The Adventures of Sadie  2009  Too $hort  actor     Bosco   3.0
# 4                 Stop Pepper Palmer  2014  Too $hort  actor   Himself   NaN

# %%
cast
# Out:
#                                                      title  year  \
# 0                                          Suuri illusioni  1985
# 1                           Gangsta Rap: The Glockumentary  2007
# 2                                        Menace II Society  1993
# 3                        Porndogs: The Adventures of Sadie  2009
# 4                                       Stop Pepper Palmer  2014
# 5                                                  Townbiz  2010
# 6                                           For Thy Love 2  2009
# 7                                             Desire (III)  2014
# 8                                  When the Man Went South  2014
# 9                                  Little Angel (Angelita)  2015
# 10                                              Mixing Nia  1998
# 11                                        The Replacements  2000
# 12                                             Dysfunktion  2015
# ...

# %% [markdown]
# ### What are the ten most common movie names of all time?

# %%
cast.title.value_counts().head(10) #wrong answer
# Out:
# Around the World in Eighty Days       1300
# 7 cajas                                689
# Thelma                                 580
# The Ten Commandments                   529
# The Eschatrilogy: Book of the Dead     517
# A Broken Code                          477
# Welcome to Essex                       443
# Stuck on You                           438
# The Dark Knight Rises                  429
# The Buccaneer                          428
# Name: title, dtype: int64

# %%
cast.title.value_counts().sum()
# Out:
# 3311647

# %%
df=cast.groupby("year").title.unique()# unique movies in each year
df=df.to_dict()
df
# Out:
# {1894: array(['Miss Jerry'], dtype=object),
#  1899: array(['Jeffries-Sharkey Contest',
#         'Battle of Jeffries and Sharkey for Championship of the World'],
#        dtype=object),
#  1900: array(['Soldiers of the Cross'], dtype=object),
#  1905: array(['Valsons'], dtype=object),
#  1906: array(['The Story of the Kelly Gang',
#         'The Joe Gans-Battling Nelson Fight', 'Lika mot lika'],
#        dtype=object),
#  1907: array(['Robbery Under Arms'], dtype=object),
#  1908: array(['The Fairylogue and Radio-Plays', 'Gans-Nelson Fight',
#         'Os Guaranis', 'Amleto'], dtype=object),
#  1909: array(["World's Heavyweight Championship Between Tommy Burns and Jack Johnson",
#         'The Life of Moses'], dtype=object),
#  1910: array(['Greven af Luxemburg', 'Ambrosius', 'Ansigttyven I',
#         'Valdemar Sejr', 'Kean', 'Amleto', 'Kapergasten', 'Jane Eyre',
#         'Re Lear', 'Pyotr Velikiy', 'Den hvide slavehandel', 'Hamlet',
# ...

# %%
x=df.values()

# %%
x
# Out:
# dict_values([array(['Miss Jerry'], dtype=object), array(['Jeffries-Sharkey Contest',
#        'Battle of Jeffries and Sharkey for Championship of the World'],
#       dtype=object), array(['Soldiers of the Cross'], dtype=object), array(['Valsons'], dtype=object), array(['The Story of the Kelly Gang',
#        'The Joe Gans-Battling Nelson Fight', 'Lika mot lika'],
#       dtype=object), array(['Robbery Under Arms'], dtype=object), array(['The Fairylogue and Radio-Plays', 'Gans-Nelson Fight',
#        'Os Guaranis', 'Amleto'], dtype=object), array(["World's Heavyweight Championship Between Tommy Burns and Jack Johnson",
#        'The Life of Moses'], dtype=object), array(['Greven af Luxemburg', 'Ambrosius', 'Ansigttyven I',
#        'Valdemar Sejr', 'Kean', 'Amleto', 'Kapergasten', 'Jane Eyre',
#        'Re Lear', 'Pyotr Velikiy', 'Den hvide slavehandel', 'Hamlet',
#        'Nelson-Wolgast Fight', 'Lucrezia Borgia (II)', 'En rekrut fra 64',
# ...

# %% [markdown]
# ### Which three years of the 1930s saw the most films released?

# %%
cast[(cast.year>=1930)&(cast.year<1940)].sort_values("year")
# Out:
#                                  title  year                      name  \
# 1700115     Du Barry, Woman of Passion  1930              Tom Ricketts
# 1816734                  In Gay Madrid  1930               David Scott
# 2847365                       Whoopee!  1930           Christine Maple
# 162309                       Moby Dick  1930           Jay (IV) Berger
# 162380           Galas de la Paramount  1930             Ludwig Berger
# 162382             Paramount on Parade  1930             Ludwig Berger
# 561137          Check and Double Check  1930  Duke Ellington Orchestra
# 561060             Paramount on Parade  1930           Dubravko Dujsin
# 1816895                     Night Work  1930             Douglas Scott
# 1816899                           Reno  1930             Douglas Scott
# 1815270               Die Lindenwirtin  1930          Leo Sch?tzendorf
# 1816900                  Sarah and Son  1930             Douglas Scott
# ...

# %%
df2=cast

# %%
df2.head()
# Out:
#                                title  year
# 0                    Suuri illusioni  1985
# 1     Gangsta Rap: The Glockumentary  2007
# 2                  Menace II Society  1993
# 3  Porndogs: The Adventures of Sadie  2009
# 4                 Stop Pepper Palmer  2014

# %%
df2.drop(["name","type","character","n"], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-4667c599e4e7> in <module>
# ----> 1 df2.drop(["name","type","character","n"], axis=1, inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
df2
# Out:
#                                                      title  year
# 511376                                          Miss Jerry  1894
# 427108                                          Miss Jerry  1894
# 2310859                                         Miss Jerry  1894
# 978078                            Jeffries-Sharkey Contest  1899
# 1839198  Battle of Jeffries and Sharkey for Championshi...  1899
# 1839203                           Jeffries-Sharkey Contest  1899
# 227301                            Jeffries-Sharkey Contest  1899
# 1295161                           Jeffries-Sharkey Contest  1899
# 978075   Battle of Jeffries and Sharkey for Championshi...  1899
# 1581218                              Soldiers of the Cross  1900
# 1581070                              Soldiers of the Cross  1900
# 552946                                             Valsons  1905
# 1330943                        The Story of the Kelly Gang  1906
# ...

# %%
df2=df2.sort_values("year")

# %%
df3=df2[(df2.year>=1930)&(df2.year<1940)].title.unique()

# %%
df3
# Out:
# array(['Der blaue Engel', 'Lotus Lady', 'The Truth About Youth', ...,
#        'Banana-da-Terra', 'Kaiss wa leila', 'Ani to sono imoto'],
#       dtype=object)

# %% [markdown]
# ### Plot the number of films that have been released each decade over the history of cinema.

# %% [markdown]
# ### Plot the number of "Hamlet" films made each decade.

# %% [markdown]
# ### Plot the number of "Rustler" characters in each decade of the history of film.

# %% [markdown]
# ### Plot the number of "Hamlet" characters each decade.

# %% [markdown]
# ### What are the 11 most common character names in movie history?

# %%
cast.character.value_counts().head(11)
# Out:
# Himself        18926
# Dancer         11015
# Extra           8638
# Reporter        7593
# Doctor          6803
# Policeman       6470
# Student         6390
# Nurse           6127
# Bartender       6123
# Minor Role      5830
# Party Guest     5820
# Name: character, dtype: int64

# %% [markdown]
# ### Who are the 10 people most often credited as "Herself" in film history?

# %%
cast[cast.character=="Herself"].name.value_counts().head(10)
# Out:
# Joyce Brothers        14
# Queen Elizabeth II    11
# Margaret Thatcher      8
# Mary Jo Pehl           7
# Joan Rivers            7
# Rekha                  5
# Marilyn Monroe         5
# Juhi Chawla            5
# Chris Evert            5
# Caroline Rhea          5
# Name: name, dtype: int64

# %% [markdown]
# ### Who are the 10 people most often credited as "Himself" in film history?

# %%
cast[cast.character=="Himself"].name.value_counts().head(10)
# Out:
# Adolf Hitler             93
# Richard Nixon            39
# Ronald Reagan            31
# John F. Kennedy          26
# Ron Jeremy               24
# Winston Churchill        20
# Bill Clinton             20
# Franklin D. Roosevelt    20
# George W. Bush           20
# Martin Luther King       19
# Name: name, dtype: int64

# %% [markdown]
# ### Which actors or actresses appeared in the most movies in the year 1945?

# %%
cast[cast.year==1945].name.value_counts().head(1)
# Out:
# Emmett Vogan    39
# Name: name, dtype: int64

# %% [markdown]
# ### Which actors or actresses appeared in the most movies in the year 1985?

# %%
cast[cast.year==1985].name.value_counts().head(1)
# Out:
# Shakti Kapoor    19
# Name: name, dtype: int64

# %% [markdown]
# ### Plot how many roles Mammootty has played in each year of his career.

# %% [markdown]
# ### What are the 10 most frequent roles that start with the phrase "Patron in"?

# %% [markdown]
# ### What are the 10 most frequent roles that start with the word "Science"?

# %% [markdown]
# ### Plot the n-values of the roles that Judi Dench has played over her career.

# %% [markdown]
# ### Plot the n-values of Cary Grant's roles through his career.

# %% [markdown]
# ### Plot the n-value of the roles that Sidney Poitier has acted over the years.

# %% [markdown]
# ### How many leading (n=1) roles were available to actors, and how many to actresses, in the 1950s?

# %% [markdown]
# ### How many supporting (n=2) roles were available to actors, and how many to actresses, in the 1950s?
