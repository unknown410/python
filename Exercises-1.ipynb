# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
cast = pd.read_csv(r'C:\Users\mani\Python\cast.csv')
cast.head()
# Out:
#                                title  year       name   type character     n
# 0                    Suuri illusioni  1985     Homo $  actor    Guests  22.0
# 1     Gangsta Rap: The Glockumentary  2007  Too $hort  actor   Himself   NaN
# 2                  Menace II Society  1993  Too $hort  actor   Lew-Loc  27.0
# 3  Porndogs: The Adventures of Sadie  2009  Too $hort  actor     Bosco   3.0
# 4                 Stop Pepper Palmer  2014  Too $hort  actor   Himself   NaN

# %%
cast
# Out:
#                                                      title  year  \
# 0                                          Suuri illusioni  1985
# 1                           Gangsta Rap: The Glockumentary  2007
# 2                                        Menace II Society  1993
# 3                        Porndogs: The Adventures of Sadie  2009
# 4                                       Stop Pepper Palmer  2014
# 5                                                  Townbiz  2010
# 6                                           For Thy Love 2  2009
# 7                                             Desire (III)  2014
# 8                                  When the Man Went South  2014
# 9                                  Little Angel (Angelita)  2015
# 10                                              Mixing Nia  1998
# 11                                        The Replacements  2000
# 12                                             Dysfunktion  2015
# ...

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
#Answer
cast.groupby("year").title.nunique().sum()
# Out:
# 173716

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
print(cast.sort_values("year").title.unique()) #all names
# Out:
# ['Miss Jerry' 'Jeffries-Sharkey Contest'
#  'Battle of Jeffries and Sharkey for Championship of the World' ...
#  'Cranium Intel: Magnetism X.3' 'Edge of Time' 'Girl Fight']

# %%
df1=cast.iloc[:,2]
df1.sort_values("year").drop_duplicate()
df1.head(2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-52630cd52829> in <module>
#       1 df1=cast.iloc[:,2]
# ----> 2 df1.sort_values("year").drop_duplicate()
#       3 df1.head(2)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in sort_values(self, axis, ascending, inplace, kind, na_position)
#    2444         """
#    2445         inplace = validate_bool_kwarg(inplace, 'inplace')
# -> 2446         axis = self._get_axis_number(axis)
#    2447
#    2448         # GH 5856/5853
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(self, axis)
#     373                 pass
#     374         raise ValueError('No axis named {0} for object type {1}'
# --> 375                          .format(axis, type(self)))
#     376
#     377     def _get_axis_name(self, axis):
#
# ...

# %%
cast.groupby("title").mean().sort_values("year").head(2)
# Out:
#                             year    n
# title
# Miss Jerry                1894.0  NaN
# Jeffries-Sharkey Contest  1899.0  1.5

# %%
cast.sort_values("year")
# Out:
#                                                      title  year  \
# 511376                                          Miss Jerry  1894
# 427108                                          Miss Jerry  1894
# 2310859                                         Miss Jerry  1894
# 978078                            Jeffries-Sharkey Contest  1899
# 1839198  Battle of Jeffries and Sharkey for Championshi...  1899
# 1839203                           Jeffries-Sharkey Contest  1899
# 227301                            Jeffries-Sharkey Contest  1899
# 1295161                           Jeffries-Sharkey Contest  1899
# 978075   Battle of Jeffries and Sharkey for Championshi...  1899
# 1581218                              Soldiers of the Cross  1900
# 1581070                              Soldiers of the Cross  1900
# 552946                                             Valsons  1905
# 1330943                        The Story of the Kelly Gang  1906
# ...

# %%
#Answer
i=0
while(i!=2):
    print(cast.sort_values("year").title.unique()[i])
    i=i+1
# Out:
# Miss Jerry
# Jeffries-Sharkey Contest

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
#Answer
cast[cast.title=="Hamlet"].year.nunique()
# Out:
# 17

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
#Answer
cast[cast.title=="North by Northwest"].year.nunique()
# Out:
# 1

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
#Answer
cast[cast.title=="Hamlet"].year.min()
# Out:
# 1910

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
#Answer
cast[cast.title=="Treasure Island"].sort_values("year")
# Out:
#                    title  year                    name     type  \
# 1304778  Treasure Island  1918         Herschel Mayall    actor
# 3258893  Treasure Island  1918      Eleanor Washington  actress
# 3026895  Treasure Island  1918        Violet Radcliffe  actress
# 1160631  Treasure Island  1918             Raymond Lee    actor
# 1188122  Treasure Island  1918            Elmo Lincoln    actor
# 837168   Treasure Island  1918            Edwin Harley    actor
# 311157   Treasure Island  1918       Francis Carpenter    actor
# 1356733  Treasure Island  1918         Buddy Messinger    actor
# 773848   Treasure Island  1918               Joe Grant    actor
# 2438589  Treasure Island  1918     Virginia Lee Corbin  actress
# 764015   Treasure Island  1918          Charles Gorman    actor
# 1578208  Treasure Island  1918              Lloyd Perl    actor
# 1790003  Treasure Island  1918           Lewis Sargent    actor
# 1395988  Treasure Island  1920            Bull Montana    actor
# ...

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
#Answer
cast[cast.year==1950].title.nunique()
# Out:
# 877

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
#Answer
cast[cast.year==1960].title.nunique()
# Out:
# 1034

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
#Answer
cast[(cast.year>=1950) & (cast.year<1960)].title.nunique()
# Out:
# 9681

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
#Answer
print(cast[cast.title=="Batman"].year.unique())
# Out:
# [1943 1989]

# %%
cast[cast.title=="Batman"].year.unique()
# Out:
# array([1943, 1989], dtype=int64)

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
#Answer
cast[cast.title=="Inception"].character.nunique()
# Out:
# 51

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
#Answer
cast[cast.title=="Inception"].n.isnull().sum()
# Out:
# 21

# %%
cast[cast.title=="Inception"].n.isnull().count()#total number of values in "n" column
# Out:
# 72

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
#Answer
cast[cast.title=="Inception"].n.dropna().count()
# Out:
# 51

# %%
cast[cast.title=="Inception"].n.dropna().shape
# Out:
# (51,)

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
#Answer
cast[cast.title=="North by Northwest"].sort_values("n").dropna().loc[:,["name","n"]]#increasing order
# Out:
#                          name     n
# 773496             Cary Grant   1.0
# 3084579       Eva Marie Saint   2.0
# 1292652           James Mason   3.0
# 2776446   Jessie Royce Landis   4.0
# 315343         Leo G. Carroll   5.0
# 2685171  Josephine Hutchinson   6.0
# 1504777           Philip Ober   7.0
# 1130557         Martin Landau   8.0
# 2167754         Adam Williams   9.0
# 1607029          Edward Platt  10.0
# 590702      Robert Ellenstein  11.0
# 2033529          Les Tremayne  12.0
# 411247        Philip Coolidge  13.0
# 1339004         Patrick McVey  14.0
# 180985           Edward Binns  15.0
# 1228229             Ken Lynch  16.0

# %%
print(cast[cast.title=="North by Northwest"].sort_values("n").dropna().name)#increasing order
# Out:
# 773496               Cary Grant
# 3084579         Eva Marie Saint
# 1292652             James Mason
# 2776446     Jessie Royce Landis
# 315343           Leo G. Carroll
# 2685171    Josephine Hutchinson
# 1504777             Philip Ober
# 1130557           Martin Landau
# 2167754           Adam Williams
# 1607029            Edward Platt
# 590702        Robert Ellenstein
# 2033529            Les Tremayne
# 411247          Philip Coolidge
# 1339004           Patrick McVey
# 180985             Edward Binns
# 1228229               Ken Lynch
# Name: name, dtype: object

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
#Answer
cast[(cast.title=="Sleuth") & (cast.year==1972)].sort_values("n")
# Out:
#           title  year                name     type  \
# 1513570  Sleuth  1972    Laurence Olivier    actor
# 288502   Sleuth  1972       Michael Caine    actor
# 330750   Sleuth  1972      Alec Cawthorne    actor
# 1299944  Sleuth  1972  John (II) Matthews    actor
# 2406762  Sleuth  1972  Eve (III) Channing  actress
# 1285278  Sleuth  1972        Teddy Martin    actor
#
#                           character    n
# 1513570                 Andrew Wyke  1.0
# 288502                  Milo Tindle  2.0
# 330750            Inspector Doppler  3.0
# 1299944  Detective Sergeant Tarrant  4.0
# 2406762             Marguerite Wyke  5.0
# 1285278      Police Constable Higgs  6.0

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
#Answer
cast[(cast.title=="Sleuth") & (cast.year==2007)].sort_values("n")
# Out:
#           title  year                 name     type          character    n
# 288503   Sleuth  2007        Michael Caine    actor             Andrew  1.0
# 1147041  Sleuth  2007             Jude Law    actor               Milo  2.0
# 1602268  Sleuth  2007        Harold Pinter    actor        Man on T.V.  3.0
# 228757   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V.  NaN
# 330751   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler  NaN
# 2406761  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke  NaN
# 2958823  Sleuth  2007    Carmel O'Sullivan  actress             Maggie  NaN

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
#Answer
cast[(cast.title=="Hamlet") & (cast.year==1921)].character.count()
# Out:
# 9

# %%
cast[(cast.title=="Hamlet") & (cast.year==1921)]
# Out:
#           title  year                    name     type         character    n
# 6662     Hamlet  1921        Fritz Achterberg    actor       Fortinbras,  9.0
# 405908   Hamlet  1921            Paul Conradi    actor      K?nig Hamlet  2.0
# 492378   Hamlet  1921        Anton De Verdier    actor           Laertes  7.0
# 1008886  Hamlet  1921         Hans Junkermann    actor          Polonius  6.0
# 1936590  Hamlet  1921            Heinz Stieda    actor           Horatio  5.0
# 2103633  Hamlet  1921  Eduard von Winterstein    actor          Claudius  4.0
# 2355176  Hamlet  1921         Mathilde Brandt  actress  K?nigin Gertrude  3.0
# 2696646  Hamlet  1921          Lilly Jacobson  actress           Ophelia  8.0
# 2945690  Hamlet  1921            Asta Nielsen  actress            Hamlet  1.0

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
#Answer
cast[(cast.title=="Hamlet") & (cast.year==1996)].character.count()
# Out:
# 55

# %%
cast[(cast.title=="Hamlet") & (cast.year==1996)].name.__contains__("Branagh")
# Out:
# False

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
#Answer
cast[cast.character=="Hamlet"].character.count()
# Out:
# 81

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
#Answer
cast[cast.character=="Ophelia"].name.nunique() #correct answer
# Out:
# 94

# %%
cast[cast.character=="Ophelia"].character.count()
# Out:
# 96

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
#Answer
cast[cast.character=="The Dude"].name.nunique()
# Out:
# 16

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
#Answer
cast[cast.character=="The Stranger"].name.nunique()
# Out:
# 184

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
#Answer
cast[cast.name=="Sidney Poitier"].character.nunique() #correct answer
# Out:
# 41

# %%
cast[cast.name=="Sidney Poitier"].character.count()
# Out:
# 43

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
#Answer
cast[cast.name=="Judi Dench"].character.nunique()
# Out:
# 44

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
#Answer
cast[(cast.year>=1940)&(cast.year<1950)&(cast.name=="Cary Grant")&(cast.n==2)].name.count()
# Out:
# 2

# %%
cast[(cast.year>=1940)&(cast.year<1950)&(cast.name=="Cary Grant")]#list of all the roles
# Out:
#                                        title  year        name   type  \
# 773458                  Arsenic and Old Lace  1944  Cary Grant  actor
# 773466                     Destination Tokyo  1943  Cary Grant  actor
# 773470          Every Girl Should Be Married  1948  Cary Grant  actor
# 773473               George White's Scandals  1945  Cary Grant  actor
# 773475                       His Girl Friday  1940  Cary Grant  actor
# 773479                I Was a Male War Bride  1949  Cary Grant  actor
# 773490  Mr. Blandings Builds His Dream House  1948  Cary Grant  actor
# 773491                             Mr. Lucky  1943  Cary Grant  actor
# 773492                             Mr. Lucky  1943  Cary Grant  actor
# 773493                      My Favorite Wife  1940  Cary Grant  actor
# 773494                         Night and Day  1946  Cary Grant  actor
# 773495             None But the Lonely Heart  1944  Cary Grant  actor
# ...

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
#Answer as n==1 is mean lead role
cast[(cast.year>=1940)&(cast.year<1950)&(cast.name=="Cary Grant")&(cast.n==1)].sort_values("year").loc[:,["character","year","n"]]
# Out:
#                     character  year    n
# 773518            Matt Howard  1940  1.0
# 773475           Walter Burns  1940  1.0
# 773520     C. K. Dexter Haven  1940  1.0
# 773508                Johnnie  1941  1.0
# 773522           Leopold Dilg  1942  1.0
# 773499  Patrick 'Pat' O'Toole  1942  1.0
# 773466          Capt. Cassidy  1943  1.0
# 773491              Joe Adams  1943  1.0
# 773492        Joe Bascopolous  1943  1.0
# 773500            Jerry Flynn  1944  1.0
# 773458      Mortimer Brewster  1944  1.0
# 773495             Ernie Mott  1944  1.0
# 773494            Cole Porter  1946  1.0
# 773497                 Devlin  1946  1.0
# 773514                   Dick  1947  1.0
# 773515                 Dudley  1947  1.0
# 773490          Jim Blandings  1948  1.0
# 773470      Dr. Madison Brown  1948  1.0
# 773479    Capt. Henri Rochard  1949  1.0

# %%
"""#Answer if n==2 is mean lead role
cast[(cast.year>=1940)&(cast.year<1950)&(cast.name=="Cary Grant")&(cast.n==2)].sort_values("year")"""
# Out:
#                    title  year        name   type    character    n
# 773493  My Favorite Wife  1940  Cary Grant  actor         Nick  2.0
# 773503    Penny Serenade  1941  Cary Grant  actor  Roger Adams  2.0

# %%
"""#Answer if n==NaN is mean lead role
cast[(cast.year>=1940)&(cast.year<1950)&(cast.name=="Cary Grant")&(cast.n!=1)&(cast.n!=2)].sort_values("year")"""
# Out:
#                           title  year        name   type   character   n
# 773473  George White's Scandals  1945  Cary Grant  actor  Cary Grant NaN
# 773535     Without Reservations  1946  Cary Grant  actor  Cary Grant NaN

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
#Answer
cast[(cast.year>=1950)&(cast.year<1960)&(cast.type=="actor")].character.count()
# Out:
# 147951

# %% [markdown]
# ### How many roles were available for actresses in the 1950s?

# %%
#Answer
cast[(cast.year>=1950)&(cast.year<1960)&(cast.type=="actress")].character.count()
# Out:
# 53969

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
#Answer
cast[(cast.year<=1980)&(cast.n==1)].character.count()
# Out:
# 61444

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
#Answer as non-leading role n==2
cast[(cast.year<=1980)&(cast.n==2)].character.count()
# Out:
# 58100

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
#Answer as n==Nan
cast[(cast.year<=1980)&(cast.n!=1)&(cast.n!=2)].character.count()
# Out:
# 989777
